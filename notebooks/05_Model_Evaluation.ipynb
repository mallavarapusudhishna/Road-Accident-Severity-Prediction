# %%
import os
import joblib
import warnings
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")
from sklearn.tree import plot_tree

# %%
model = joblib.load("../models/final_model.pkl")

preprocessor = joblib.load("../models/preprocessor.pkl")

feature_names = joblib.load("../models/feature_names.pkl")

print("Model Loaded Successfully!")
print("Preprocessor Loaded Successfully!")
print("Feature Names Loaded Successfully!")
# Out:
# Model Loaded Successfully!
# Preprocessor Loaded Successfully!
# Feature Names Loaded Successfully!

# %%
print("Model Type:")
print(type(model))

print("\nNumber of Features:")
print(len(feature_names))
# Out:
# Model Type:
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
#
# Number of Features:
# 137

# %%
importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

display(importance.head(20))
# Out:
#                                        Feature  Importance
# 2                           speed_limit_(km/h)    0.130455
# 3                                   driver_age    0.062276
# 86                          vehicle_type_Cycle    0.038420
# 107  traffic_control_presence_Police Checkpost    0.024784
# 125                        time_of_day_Morning    0.020832
# 1                                 num_vehicles    0.020639
# 0                                         year    0.020257
# 87                     vehicle_type_Pedestrian    0.017190
# 131                              is_weekend_No    0.017053
# 95                  road_type_National Highway    0.016415
# 72                                   month_May    0.016050
# 99                      road_condition_Damaged    0.014794
# 93                               weather_Rainy    0.014093
# 122                      time_of_day_Afternoon    0.013873
# 103                   lighting_conditions_Dark    0.013845
# 52                              city_New Delhi    0.013805
# 74                               month_October    0.013697
# 117                       alcohol_involved_Yes    0.013309
# 80                        day_of_week_Thursday    0.012819
# 123                        time_of_day_Evening    0.012809

# %%
importance.to_csv(
    "../models/feature_importance.csv",
    index=False
)

# %%
plt.figure(figsize=(10,8))

sns.barplot(
    data=importance.head(20),
    x="Importance",
    y="Feature",
    palette="viridis"
)

plt.title("Top 20 Important Features")

plt.show()

# %%
importance.to_csv(
    "../models/feature_importance.csv",
    index=False
)

print("Feature Importance Saved!")
# Out:
# Feature Importance Saved!

# %%
df = joblib.load("../data/processed/final_dataframe.pkl")

print(df.shape)

df.head()
# Out:
# (3000, 30)
#                state     city  year    month day_of_week   time severity  \
# 0  Jammu and Kashmir  Unknown  2021      May      Monday   1:46  Serious
# 1      Uttar Pradesh  Lucknow  2018  January   Wednesday  21:30    Minor
# 2       Chhattisgarh  Unknown  2023      May   Wednesday   5:37    Minor
# 3      Uttar Pradesh  Lucknow  2020     June    Saturday   0:31    Minor
# 4             Sikkim  Unknown  2021   August    Thursday  11:21    Minor
#
#    num_vehicles vehicle_type  number_of_casualties  ...  alcohol_involved  \
# 0             5        Cycle                     0  ...               Yes
# 1             5        Truck                     5  ...               Yes
# 2             5   Pedestrian                     6  ...                No
# 3             3          Bus                    10  ...               Yes
# 4             5        Cycle                     7  ...                No
#
#   accident_location_details accident_hour time_of_day driver_age_group  \
# 0                     Curve             1  Late Night           Senior
# 1             Straight Road            21     Evening            Adult
# 2                    Bridge             5     Morning            Adult
# 3             Straight Road             0  Late Night            Adult
# 4              Intersection            11     Morning            Adult
#
#   is_multi_vehicle  is_weekend  is_night is_peak_hour target_severity
# 0              Yes          No       Yes           No               1
# 1              Yes          No       Yes           No               0
# 2              Yes          No       Yes           No               0
# 3              Yes         Yes       Yes           No               0
# 4              Yes          No        No           No               0
#
# [5 rows x 30 columns]

# %%
def generate_prediction_explanation(row, prediction):

    reasons = []

    if row["alcohol_involved"] == "Yes":
        reasons.append("alcohol involvement")

    if row["road_type"] == "National Highway":
        reasons.append("highway driving")

    if row["road_condition"] == "Wet":
        reasons.append("wet road")

    if row["lighting_conditions"] == "Dark":
        reasons.append("poor lighting")

    if row["speed_limit_(km/h)"] >= 80:
        reasons.append("high speed")

    if row["is_night"] == "Yes":
        reasons.append("night driving")

    if len(reasons) == 0:
        explanation = (
            "The model predicted this accident severity because no major "
            "high-risk factors were detected in the available features."
        )
    else:
        explanation = (
            f"The model predicted '{prediction}' because the accident involved "
            + ", ".join(reasons[:-1])
            + (" and " if len(reasons) > 1 else "")
            + reasons[-1]
            + ". These were among the strongest contributing risk factors."
        )

    return explanation

# %%
reverse_map = {
    0: "Minor",
    1: "Serious",
    2: "Fatal"
}

print("MODEL PREDICTIONS")

for i in range(5):

    sample = df.iloc[[i]]        # Keep as DataFrame

    sample_features = sample.drop(
        columns=[
            "severity",
            "target_severity"
        ],
        errors="ignore"
    )

    sample_processed = preprocessor.transform(sample_features)

    prediction_encoded = model.predict(sample_processed)[0]

    prediction = reverse_map[prediction_encoded]

    print(f"\nSample {i+1}")
    print("Predicted Severity :", prediction)

    print(generate_prediction_explanation(
        sample.iloc[0],
        prediction
    ))
# Out:
# MODEL PREDICTIONS
#
# Sample 1
# Predicted Severity : Minor
# The model predicted 'Minor' because the accident involved alcohol involvement, highway driving, wet road, poor lighting and night driving. These were among the strongest contributing risk factors.
#
# Sample 2
# Predicted Severity : Minor
# The model predicted 'Minor' because the accident involved alcohol involvement, high speed and night driving. These were among the strongest contributing risk factors.
#
# Sample 3
# Predicted Severity : Serious
# The model predicted 'Serious' because the accident involved highway driving, high speed and night driving. These were among the strongest contributing risk factors.
#
# Sample 4
# Predicted Severity : Fatal
# The model predicted 'Fatal' because the accident involved alcohol involvement, poor lighting and night driving. These were among the strongest contributing risk factors.
#
# Sample 5
# Predicted Severity : Minor
# The model predicted 'Minor' because the accident involved wet road and high speed. These were among the strongest contributing risk factors.

# %%
print("PROJECT EVALUATION COMPLETED")

print("Final Production Model :", type(model).__name__)
print("Top Important Feature :", importance.iloc[0]["Feature"])
print("Evaluation Completed Successfully")
# Out:
# PROJECT EVALUATION COMPLETED
# Final Production Model : DecisionTreeClassifier
# Top Important Feature : speed_limit_(km/h)
# Evaluation Completed Successfully

# %% [markdown]
# ## Limitations
#
# - The dataset contains limited predictive information.
# - Many features show weak relationships with the target.
# - Additional variables such as traffic density, vehicle speed, and driver behavior could improve performance.
